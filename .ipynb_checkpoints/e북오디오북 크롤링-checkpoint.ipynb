# %%
pip install selenium beautifulsoup4
# Out:
# Requirement already satisfied: selenium in c:\users\hun\anaconda3\lib\site-packages (4.31.0)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: beautifulsoup4 in c:\users\hun\anaconda3\lib\site-packages (4.12.3)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\hun\anaconda3\lib\site-packages (from urllib3[socks]<3,>=1.26->selenium) (2.2.3)
# Requirement already satisfied: trio~=0.17 in c:\users\hun\anaconda3\lib\site-packages (from selenium) (0.29.0)
# Requirement already satisfied: trio-websocket~=0.9 in c:\users\hun\anaconda3\lib\site-packages (from selenium) (0.12.2)
# Requirement already satisfied: certifi>=2021.10.8 in c:\users\hun\anaconda3\lib\site-packages (from selenium) (2025.1.31)
# Requirement already satisfied: typing_extensions~=4.9 in c:\users\hun\anaconda3\lib\site-packages (from selenium) (4.11.0)
# Requirement already satisfied: websocket-client~=1.8 in c:\users\hun\anaconda3\lib\site-packages (from selenium) (1.8.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\hun\anaconda3\lib\site-packages (from beautifulsoup4) (2.5)
# Requirement already satisfied: attrs>=23.2.0 in c:\users\hun\anaconda3\lib\site-packages (from trio~=0.17->selenium) (25.3.0)
# Requirement already satisfied: sortedcontainers in c:\users\hun\anaconda3\lib\site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: idna in c:\users\hun\anaconda3\lib\site-packages (from trio~=0.17->selenium) (3.7)
# Requirement already satisfied: outcome in c:\users\hun\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.3.0.post0)
# Requirement already satisfied: sniffio>=1.3.0 in c:\users\hun\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.3.0)
# Requirement already satisfied: cffi>=1.14 in c:\users\hun\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.17.1)
# Requirement already satisfied: wsproto>=0.14 in c:\users\hun\anaconda3\lib\site-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in c:\users\hun\anaconda3\lib\site-packages (from urllib3[socks]<3,>=1.26->selenium) (1.7.1)
# Requirement already satisfied: pycparser in c:\users\hun\anaconda3\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.21)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\hun\anaconda3\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from bs4 import BeautifulSoup
import time
import pandas as pd

# 셀레니움 옵션
options = Options()
# options.add_argument('--headless')  # 일단 눈으로 보려고 비활성화
options.add_argument('--no-sandbox')
options.add_argument('--disable-dev-shm-usage')
options.add_argument('user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/122.0.0.0 Safari/537.36')

driver = webdriver.Chrome(service=Service(), options=options)

# 🔥 "일반 e북" URL로 이동
url = "https://ebook.kyobobook.co.kr/dig/etc/landing/best?lsc=AUD"
driver.get(url)

time.sleep(5)  # 충분히 기다려주자

soup = BeautifulSoup(driver.page_source, 'html.parser')

# 🔥 prodDt 하나하나 가져오기
products = soup.select('div.prodDt')

data = []

for prod in products:
    try:
        # 순위
        rank_tag = prod.select_one('em.rank')
        rank = rank_tag.text.strip() if rank_tag else None
        
        # 제목
        title_tag = prod.select_one('h3 a')
        title = title_tag.text.strip() if title_tag else None
        
        # 상세페이지 링크
        detail_link = title_tag['href'] if title_tag else None
        
        # 저자, 출판사, 출판일 (순서 주의)
        info_spans = prod.select('p.prodDt_info span')
        author = info_spans[0].text.strip() if len(info_spans) > 0 else None
        publisher = info_spans[1].text.strip() if len(info_spans) > 1 else None
        pub_date = info_spans[2].text.strip() if len(info_spans) > 2 else None
        
        # 가격
        price_tag = prod.select_one('div.prodDt_price span b')
        price = price_tag.text.strip() if price_tag else None
        
        data.append({
            '순위': rank,
            '제목': title,
            '상세링크': detail_link,
            '저자': author,
            '출판사': publisher,
            '출판일': pub_date,
            '가격': price
        })
    except Exception as e:
        print("❌ 에러 발생:", e)

driver.quit()

# ✅ 데이터프레임 변환 및 출력
df = pd.DataFrame(data)
print(df)

# CSV 저장
df.to_csv('kyobo_ebook_best.csv', index=False, encoding='utf-8-sig')
# Out:
# Empty DataFrame
# Columns: []
# Index: []
